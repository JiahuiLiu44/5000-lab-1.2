# %% [markdown]
# # Impromptu Bibtex Find and Merge Tool
#
# ## Introduction
#
# - MJ Marchywka's bash script for scraping BibTeX entries from arbitrary
# webpages.
# - hunt for a "BibTeX citation" button or manually copy and paste formatted
# citations.
#
# ## Script Overview
#
# -this bash script automates the process of extracting BibTeX citations
# from arbitrary web pages, streamlining the workflow for researchers.
#
# -The script avoids manual efforts such as hunting for a BibTeX citation
# button or copying formatted citations.

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generate data
x = np.linspace(0, 10, 100)
y = np.sin(x)

# Plot the data
plt.plot(x, y)
plt.title("Sine Wave Plot")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.show()
